# %% [markdown]
# # Markdown CheatSheet

# %% [markdown]
# ### What is a Jupyter Notebook anyway?
#
# Notebooks can be described as 'executable documents' where code and documentation are colocated within the same dynamic environment. This format combines rich presentation and documentation with working executable code. A notebook is essentially a 'one stop shop' for creating working software that is intended to be shared with your peers or with a broad audience.
#
# ### Why should I use them?
#
# Notebooks provide you with the ability to write code interactively and perform an analysis.  They also are extremely portable as they can be exported individually as code or as HTML pages.  This enables the easy transfer of knowledge between parties.  Notebooks use a language similar to HTML called Markdown to create HTML presentations.  Some example Markdown code can be seen below:
#
# Here is a markdown cheatsheet, want to see the code? just **double click** on the cell!
#
# ### Headers:
#
# # H1
# ## H2
#
#
# ### Fonts:
#
# *Italics*
#
# **Bold**
#
# ***Bold and italicized***
#
# ~~strikethrough~~
#
#
# ### Lists:
#
# 1. First ordered list item
# 2. Another item
# ⋅⋅* Unordered sub-list.
# 1. Actual numbers don't matter, just that it's a number
# ⋅⋅1. Ordered sub-list
# 4. And another item.
#
#    You can have properly indented paragraphs within list items. Notice the blank line above, and the leading spaces (at least      one, but we'll use three here to also align the raw Markdown).
#
#    To have a line break without a paragraph, you will need to use two trailing spaces.
#    Note that this line is separate, but within the same paragraph.
#
#
# * Unordered list can use asterisks
# - Or minuses
# + Or pluses
#
# ### Links:
#
# [I'm an inline-style link](https://www.google.com)
#
# [I'm an inline-style link with title](https://www.google.com "Google's Homepage")
#
# [I'm a reference-style link][Arbitrary case-insensitive reference text]
#
# Or leave it empty and use the [link text itself].
#
# URLs and URLs in angle brackets will automatically get turned into links.
# http://www.example.com or <http://www.example.com> and sometimes
# example.com (but not on Github, for example).
#
# Some text to show that the reference links can follow later.
#
# [link text itself]: http://www.google.com
#
#
# ### Images:
#
# Here's our logo (hover to see the title text):
#
# Inline-style:
# ![alt text](https://www.footlocker.eu/INTERSHOP/static/WFS/Footlocker-Footlocker_EU-Site/-/-/en_GB/images/brand/footlocker-logo-1440.png "Approved")
#
# Reference-style:
# ![alt text][logo]
#
# [logo]: https://www.footlocker.eu/INTERSHOP/static/WFS/Footlocker-Footlocker_EU-Site/-/-/en_GB/images/brand/footlocker-logo-1440.png "Still Approved"
#
#
# ### Tables:
#
# Colons can be used to align columns.
#
# | Tables        | Are           | Cool
# | ------------- |:-------------:| -----:|
# | col 3 is      | right-aligned | 1600  |
# | col 2 is      | centered      |   12  |
# | zebra stripes | are neat      |    1  |
#
#
# There must be at least 3 dashes separating each header cell.
# The outer pipes (|) are optional, and you don't need to make the
# raw Markdown line up prettily. You can also use inline Markdown.
#
# Markdown | Less | Pretty
# --- | --- | ---
# *Still* | `renders` | **nicely**
# 1 | 2 | 3
#
#
# ### Qoutes:
#
# > "This is a very long line that will still be quoted properly when it wraps. Oh boy let's keep writing to make sure this is long enough to actually wrap for everyone. Oh, you can *put* **Markdown** into a blockquote."
#
#
# ### Maths:
#
# Reverand Bayes would be proud:
# $$ P(A \mid B) = \frac{P(B \mid A) \, P(A)} {P(B)} $$
